# %%
#Step 1 #Libraries Import
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb 
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
#Step 2 Loading the Dataset
df= pd.read_csv('/content/Employee attrition data.csv')

# %%
#Data Visualisation

# %%
df.shape
# Out:
# (4410, 29)

# %%
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
df.tail()
# Out:
#       EmployeeID  Age Attrition BusinessTravel              Department  \
# 4405        4406   42        No  Travel_Rarely  Research & Development
# 4406        4407   29        No  Travel_Rarely  Research & Development
# 4407        4408   25        No  Travel_Rarely  Research & Development
# 4408        4409   42        No  Travel_Rarely                   Sales
# 4409        4410   40        No  Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 4405                 5          4        Medical              1  Female  ...
# 4406                 2          4        Medical              1    Male  ...
# 4407                25          2  Life Sciences              1    Male  ...
# 4408                18          2        Medical              1    Male  ...
# 4409                28          3        Medical              1    Male  ...
#
#       TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
df['NumCompaniesWorked'].median()
# Out:
# 2.0

# %%
df['EnvironmentSatisfaction'].mode()
# Out:
# 0    3.0
# dtype: float64

# %%
df['JobSatisfaction'].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
df['WorkLifeBalance'].mode()
# Out:
# 0    3.0
# dtype: float64

# %%
sb.countplot(x="Attrition",hue= "Gender",data=df)

# %%
df.nunique()
# Out:
# EmployeeID                 4410
# Age                          43
# Attrition                     2
# BusinessTravel                3
# Department                    3
# DistanceFromHome             29
# Education                     5
# EducationField                6
# EmployeeCount                 1
# Gender                        2
# JobLevel                      5
# JobRole                       9
# MaritalStatus                 3
# MonthlyIncome              1349
# NumCompaniesWorked           10
# Over18                        1
# PercentSalaryHike            15
# StandardHours                 1
# StockOptionLevel              4
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# YearsAtCompany               37
# YearsSinceLastPromotion      16
# YearsWithCurrManager         18
# EnvironmentSatisfaction       4
# JobSatisfaction               4
# WorkLifeBalance               4
# JobInvolvement                4
# PerformanceRating             2
# ...

# %%
df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df['Gender'].unique()

#Male
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['JobLevel'].unique()
# Out:
# array([1, 4, 3, 2, 5])

# %%
df['JobRole'].unique()
# Out:
# array(['Healthcare Representative', 'Research Scientist',
#        'Sales Executive', 'Human Resources', 'Research Director',
#        'Laboratory Technician', 'Manufacturing Director',
#        'Sales Representative', 'Manager'], dtype=object)

# %%
df['MaritalStatus'].unique()
# Out:
# array(['Married', 'Single', 'Divorced'], dtype=object)

# %%
df['StockOptionLevel'].unique()
# Out:
# array([0, 1, 3, 2])

# %%
df['EnvironmentSatisfaction'].unique()
# Out:
# array([ 3.,  2.,  4.,  1., nan])

# %%
df['JobSatisfaction'].unique()
# Out:
# array([ 4.,  2.,  1.,  3., nan])

# %%
df['WorkLifeBalance'].unique()
# Out:
# array([ 2.,  4.,  1.,  3., nan])

# %%
df['JobInvolvement'].unique()
# Out:
# array([3, 2, 1, 4])

# %%
df['PerformanceRating'].unique()
# Out:
# array([3, 4])

# %%
#Step 4 Data Wrangling 
#4.1 Treating Null Values 
#4.2 Dropping Irrelevant Columns 
#4.3 One hot Encoding and Label Encoding

# %%
#Important : Use Mode()[0] instead of mode()
# Step 4.1 Treating null values 
df['NumCompaniesWorked'].fillna(df['NumCompaniesWorked'].mode()[0], inplace=True)
df['EnvironmentSatisfaction'].fillna(df['EnvironmentSatisfaction'].mode()[0], inplace=True)
df['JobSatisfaction'].fillna(df['JobSatisfaction'].mode()[0], inplace=True)
df['WorkLifeBalance'].fillna(df['WorkLifeBalance'].mode()[0], inplace=True)

df['TotalWorkingYears'].fillna(df['TotalWorkingYears'].median(), inplace=True)

# %%
df.value_counts("Department")
# Out:
# Department
# Research & Development    2883
# Sales                     1338
# Human Resources            189
# dtype: int64

# %%
df.value_counts("Attrition")
# Out:
# Attrition
# No     3699
# Yes     711
# dtype: int64

# %%
df.value_counts("MaritalStatus")
# Out:
# MaritalStatus
# Married     2019
# Single      1410
# Divorced     981
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
#4.2 Dropping Irrelevant Columns 

df.drop(['EmployeeID',"EmployeeCount","Over18","StandardHours"],axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   Gender                   4410 non-null   object
#  8   JobLevel                 4410 non-null   int64
#  9   JobRole                  4410 non-null   object
#  10  MaritalStatus            4410 non-null   object
#  11  MonthlyIncome            4410 non-null   int64
#  12  NumCompaniesWorked       4410 non-null   float64
#  13  PercentSalaryHike        4410 non-null   int64
# ...

# %%
sb.set(rc = {'figure.figsize':(15,7)})
sb.heatmap(df.corr(),cmap= "Blues",annot=True)

# %%
#4.3 One hot encoding and Label Encoding 
attrition = pd.get_dummies(df["Attrition"],prefix="Attrition",drop_first=True)
attrition
# Out:
#       Attrition_Yes
# 0                 0
# 1                 1
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 4405              0
# 4406              0
# 4407              0
# 4408              0
# 4409              0
#
# [4410 rows x 1 columns]

# %%
gender = pd.get_dummies(df["Gender"],prefix="gen",drop_first=True)
gender
# Out:
#       gen_Male
# 0            0
# 1            0
# 2            1
# 3            1
# 4            1
# ...        ...
# 4405         0
# 4406         1
# 4407         1
# 4408         1
# 4409         1
#
# [4410 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le_columns = ['Department','EducationField','JobRole','MaritalStatus']
df[le_columns]= df[le_columns].apply(le.fit_transform)

# %%
#Business Travel Ordinal Value COnversion 

bt_dict = {'Non-Travel' : 0 ,'Travel_Rarely' : 1,'Travel_Frequently' : 2}
df['BusinessTravel_Ord']= df.BusinessTravel.map(bt_dict)
df['BusinessTravel_Ord']
# Out:
# 0       1
# 1       2
# 2       2
# 3       0
# 4       1
#        ..
# 4405    1
# 4406    1
# 4407    1
# 4408    1
# 4409    1
# Name: BusinessTravel_Ord, Length: 4410, dtype: int64

# %%
df
# Out:
#       Age Attrition     BusinessTravel  Department  DistanceFromHome  \
# 0      51        No      Travel_Rarely           2                 6
# 1      31       Yes  Travel_Frequently           1                10
# 2      32        No  Travel_Frequently           1                17
# 3      38        No         Non-Travel           1                 2
# 4      32        No      Travel_Rarely           1                10
# ...   ...       ...                ...         ...               ...
# 4405   42        No      Travel_Rarely           1                 5
# 4406   29        No      Travel_Rarely           1                 2
# 4407   25        No      Travel_Rarely           1                25
# 4408   42        No      Travel_Rarely           2                18
# 4409   40        No      Travel_Rarely           1                28
#
#       Education  EducationField  Gender  JobLevel  JobRole  ...  \
# 0             2               1  Female         1        0  ...
# ...

# %%
df1 = pd.concat([attrition,gender,df],axis = 1)
df1
# Out:
#       Attrition_Yes  gen_Male  Age Attrition     BusinessTravel  Department  \
# 0                 0         0   51        No      Travel_Rarely           2
# 1                 1         0   31       Yes  Travel_Frequently           1
# 2                 0         1   32        No  Travel_Frequently           1
# 3                 0         1   38        No         Non-Travel           1
# 4                 0         1   32        No      Travel_Rarely           1
# ...             ...       ...  ...       ...                ...         ...
# 4405              0         0   42        No      Travel_Rarely           1
# 4406              0         1   29        No      Travel_Rarely           1
# 4407              0         1   25        No      Travel_Rarely           1
# 4408              0         1   42        No      Travel_Rarely           2
# 4409              0         1   40        No      Travel_Rarely           1
#
# ...

# %%
df1.drop(["BusinessTravel","Gender","Attrition"],axis = 1, inplace = True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Attrition_Yes            4410 non-null   uint8
#  1   gen_Male                 4410 non-null   uint8
#  2   Age                      4410 non-null   int64
#  3   Department               4410 non-null   int64
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   int64
#  7   JobLevel                 4410 non-null   int64
#  8   JobRole                  4410 non-null   int64
#  9   MaritalStatus            4410 non-null   int64
#  10  MonthlyIncome            4410 non-null   int64
#  11  NumCompaniesWorked       4410 non-null   float64
#  12  PercentSalaryHike        4410 non-null   int64
#  13  StockOptionLevel         4410 non-null   int64
# ...

# %%
df1.head()
# Out:
#    Attrition_Yes  gen_Male  Age  Department  DistanceFromHome  Education  \
# 0              0         0   51           2                 6          2
# 1              1         0   31           1                10          1
# 2              0         1   32           1                17          4
# 3              0         1   38           1                 2          5
# 4              0         1   32           1                10          1
#
#    EducationField  JobLevel  JobRole  MaritalStatus  ...  \
# 0               1         1        0              1  ...
# 1               1         1        6              2  ...
# 2               4         4        7              1  ...
# 3               1         3        1              1  ...
# 4               3         1        7              2  ...
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      6               1                        0
# ...

# %%
plt.figure(figsize=(6,4))
sb.boxplot(x="Age",data = df1)

# %%
plt.figure(figsize=(6,4))
sb.boxplot(x="MonthlyIncome",data = df1)

# %%
upp_limit = df1['MonthlyIncome'].quantile(.925)
low_limit = df1['MonthlyIncome'].quantile(0.01)

df1 = df1[(df1['MonthlyIncome']<upp_limit)& (df1['MonthlyIncome']>low_limit)]

# %%
plt.figure(figsize=(6,4))
sb.boxplot(x="MonthlyIncome",data = df1)

# %%
df1.shape
# Out:
# (4032, 25)

# %%
sb.set(rc = {'figure.figsize':(20,12)})
sb.heatmap(df1.corr(),cmap= "Blues",annot=True)

# %%
#plt.figure(figsize=(4,4))
#plt.pie(x= attrition, labels=df1['JobSatisfaction'].unique(), autopct='%1.1f%%')

# %%
plt.figure(figsize=(4,4))
sb.countplot(x= "Attrition_Yes", data=df1)

# %%
plt.figure(figsize=(4,4))
sb.countplot(x= "Attrition_Yes", hue = "gen_Male", data=df1)

# %%
#Attrition rate for diff genders
df1[['gen_Male',"Attrition_Yes"]].groupby('gen_Male')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates for males")
# Out:
# Text(0.5, 0.98, 'Attrition rates for males')

# %%
df1[['JobSatisfaction',"Attrition_Yes"]].groupby('JobSatisfaction')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the job satisfaction")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the job satisfaction')

# %%
df1[['WorkLifeBalance',"Attrition_Yes"]].groupby('WorkLifeBalance')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the Work Life Balance")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the Work Life Balance')

# %%
df1[['Age',"Attrition_Yes"]].groupby('Age')["Attrition_Yes"].sum().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the Age")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the Age')

# %%
df1[['EducationField',"Attrition_Yes"]].groupby('EducationField')["Attrition_Yes"].sum().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the education field")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the education field')

# %%
df1[['JobRole',"Attrition_Yes"]].groupby('JobRole')["Attrition_Yes"].sum().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the JobLevel")

df1.sort_values("Attrition_Yes",inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df1[['MaritalStatus',"Attrition_Yes"]].groupby('MaritalStatus')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the Age")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the Age')

# %%
df1[['NumCompaniesWorked',"Attrition_Yes"]].groupby('NumCompaniesWorked')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the monthly Income")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the monthly Income')

# %%
df1[['StockOptionLevel',"Attrition_Yes"]].groupby('StockOptionLevel')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the monthly Income")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the monthly Income')

# %%
df1[['PercentSalaryHike',"Attrition_Yes"]].groupby('PercentSalaryHike')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the monthly Income")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the monthly Income')

# %%
df1[['TotalWorkingYears',"Attrition_Yes"]].groupby('TotalWorkingYears')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the monthly Income")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the monthly Income')

# %%
df1[['TrainingTimesLastYear',"Attrition_Yes"]].groupby('TrainingTimesLastYear')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the monthly Income")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the monthly Income')

# %%
df1[['YearsAtCompany',"Attrition_Yes"]].groupby('YearsAtCompany')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the monthly Income")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the monthly Income')

# %%
df1[['YearsSinceLastPromotion',"Attrition_Yes"]].groupby('YearsSinceLastPromotion')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the monthly Income")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the monthly Income')

# %%
df1[['YearsWithCurrManager',"Attrition_Yes"]].groupby('YearsWithCurrManager')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the monthly Income")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the monthly Income')

# %%
df1[['EnvironmentSatisfaction',"Attrition_Yes"]].groupby('EnvironmentSatisfaction')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the EnvironmentSatisfaction")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the EnvironmentSatisfaction')

# %%
df1[['JobSatisfaction',"Attrition_Yes"]].groupby('JobSatisfaction')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the JobSatisfaction")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the JobSatisfaction')

# %%
df1[['WorkLifeBalance',"Attrition_Yes"]].groupby('WorkLifeBalance')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the WorkLifeBalance")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the WorkLifeBalance')

# %%
df1[['JobInvolvement',"Attrition_Yes"]].groupby('JobInvolvement')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the JobInvolvement")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the JobInvolvement')

# %%
df1[['PerformanceRating',"Attrition_Yes"]].groupby('PerformanceRating')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the PerformanceRating")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the PerformanceRating')

# %%
df1[['BusinessTravel_Ord',"Attrition_Yes"]].groupby('BusinessTravel_Ord')["Attrition_Yes"].mean().plot(kind='bar',figsize=(6,4))
plt.suptitle("Attrition rates as per the BusinessTravel_Ord")
# Out:
# Text(0.5, 0.98, 'Attrition rates as per the BusinessTravel_Ord')

# %%
#Step 6a Building the Logistic Regression Model

#6a.1 Defining the Features and Targets 

x = df1.drop("Attrition_Yes",axis= 1)
y= df1["Attrition_Yes"]

# %%
#Split x and y into training and testing set of 70:30

x_train,x_test,y_train, y_test = train_test_split(x,y,test_size= .30, random_state = 42)

# %%
#Fitting the Model
Hr_model = LogisticRegression()
Hr_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = Hr_model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
#Predicting the training accuracy 
Hr_model.score(x_train,y_train)
# Out:
# 0.8327427356484762

# %%
#Testing Accuacy
Hr_model.score(x_test, y_test)
# Out:
# 0.8446280991735537

# %%
#Classification: Precision, Recall, F1 Score
from sklearn import metrics
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.92      1022
#            1       0.00      0.00      0.00       188
#
#     accuracy                           0.84      1210
#    macro avg       0.42      0.50      0.46      1210
# weighted avg       0.71      0.84      0.77      1210
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
#Step 6b 
#Applying Random Forest to see if we can improve the accuracy but first implementing feature importance 
x = df1.iloc[:,1:]
y = df1.iloc[:,0:1]

# %%
#Splitting x and y 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30)

# %%
#Importing Random Forest and Fitting it
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit (x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestClassifier()

# %%
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
# Out:
# RandomForestClassifier(n_jobs=1)

# %%
#Feature Importance
feature_imp = pd.Series(rf.feature_importances_,index=x.columns).sort_values(ascending=False)
feature_imp
# Out:
# Age                        0.094791
# TotalWorkingYears          0.086855
# MonthlyIncome              0.080867
# YearsAtCompany             0.065073
# DistanceFromHome           0.058239
# PercentSalaryHike          0.054383
# NumCompaniesWorked         0.049583
# YearsWithCurrManager       0.047351
# JobRole                    0.043178
# MaritalStatus              0.038712
# YearsSinceLastPromotion    0.037913
# TrainingTimesLastYear      0.035524
# JobSatisfaction            0.034628
# EnvironmentSatisfaction    0.033940
# Education                  0.033888
# WorkLifeBalance            0.032377
# EducationField             0.031819
# JobLevel                   0.030868
# JobInvolvement             0.026110
# BusinessTravel_Ord         0.025020
# StockOptionLevel           0.022223
# Department                 0.017345
# gen_Male                   0.011888
# PerformanceRating          0.007425
# dtype: float64

# %%
#Representing Feature Importance visually
sb.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#Step 6c 
#Applying Random Forest by removing unnecesaary Features
x = df1.drop(["Attrition_Yes","Department","gen_Male","PerformanceRating"],axis = 1)
y = df1.iloc[:,0:1]

# %%
#Splitting the Training and Testing set
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30)

# %%
#Fitting the Model
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit (x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestClassifier()

# %%
y_pred = rf.predict (x_test)
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
#Testing Accuracy
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9809917355371901

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1025
#            1       0.96      0.89      0.93       185
#
#     accuracy                           0.98      1210
#    macro avg       0.97      0.94      0.96      1210
# weighted avg       0.98      0.98      0.98      1210

# %%
#AUC for testing set 

from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.9511272247857614

# %%
#Plotting a graph for training and testing AUC by Applying a for loop to find appropriate # estimators  

n_estimators = [1, 2, 4, 8, 16, 32, 64, 100, 200]
train_results= []
test_results = []
for estimator in n_estimators:
  rf = RandomForestClassifier(n_estimators=estimator, n_jobs=-1)
  rf.fit(x_train, y_train)

  train_pred = rf.predict(x_train)
  false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
  roc_auc = auc(false_positive_rate, true_positive_rate)
  train_results.append(roc_auc)
  y_pred = rf.predict(x_test)
  false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
  roc_auc = auc(false_positive_rate, true_positive_rate)
  test_results.append(roc_auc)

from matplotlib.legend_handler import HandlerLine2D
line1,= plt.plot(n_estimators, train_results,"b",label= "Train AUC")
line2, = plt.plot(n_estimators, test_results, "r",label="Test AUC")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel("AUC score")
plt.xlabel ("n estimators")
plt.figure(figsize=(8,4))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# ...
